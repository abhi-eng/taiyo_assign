# %%
import requests
import json
import os
import pandas as pd
import time
from selenium import webdriver
from bs4 import BeautifulSoup

# %% [markdown]
# ## NASA Earth Data

# %%
class Weather_API:
    
    def __init__ (self, keyword):
        self.keyword = keyword
        
    def json_print(self, obj):
        # create a formatted string of the Python JSON object
        with open('api_data.txt', 'w') as json_file:
            json.dump(obj, json_file)
        text = json.dumps(obj, sort_keys=True, indent=4)
        print(text)
        
    def create_dataframe(self, obj):
        
        # creating a dataframe from nested JSON objects
        FIELDS = ["source.id", "source.name", "author", "title", "description", "url", "urlToImage", "publishedAt", "content"]
        df = pd.json_normalize(obj['articles'])
        final_df = df[FIELDS]
        #final_df.set_index('source.id', inplace = True)
        display(final_df.head())

    
    def news_api(self):
        
        # Use the news-api to obtain articles published from
        url = ('https://newsapi.org/v2/everything?'
       'q={keyword}&'
       'apiKey=4e70cabb80884db08524a28ac33cdc1d'.format(keyword = self.keyword))
        
        
        response = requests.get(url)
        if (response.status_code == 200):
            print('API call successful!')
            json_response = response.json()
            if(len(json_response['articles']) == 0):
                print('No News Articles Found')
            else:
                
                # Print a String in Json Format
                self.json_print(json_response)
                
                
                
                # Create a pandas DataFrame
                self.create_dataframe(json_response)
                    
        else:
            print('Status code: ', response.status_code)

# %%
class Web_Scraping:
    
    def __init__(self, location):
        self.location = location
        
    def selenium_webdriver(self):
        
        # Start the Driver
        driver = webdriver.Chrome(executable_path = r"C:\Users\Aditya\Downloads\chromedriver_win32\chromedriver.exe")
        
        # Hit the url of NASA Earth Data website and wait for 15 seconds.
        url = ('https://earthdata.nasa.gov/search?q={location}'.format(location = self.location))
        driver.get(url)
        time.sleep(15)
        
        # Driver scrolls down 25 times to load the table.
        for i in range(0,30):
            driver.execute_script("window.scrollBy(0,6000)")
            time.sleep(10)
            
        # Fetch the webpage and store in a variable.
        webpage = driver.page_source
        
        # Parse the page using BeautifulSoup
        HTMLPage = BeautifulSoup(webpage, 'html.parser')
        
        titles = []
        description = []
        links = []

        for lists in HTMLPage.find_all(class_ = 'result'):
            if (lists.span.text != '' and len(lists.find_all('p')) != 0):
                titles.append(lists.span.text)
                description.append(lists.find('p', class_ = '').text)
                links.append(lists.find('p', class_ = 'search-link').text)
        
        # Create a DataFrame
        df = pd.DataFrame(list(zip(titles, description, links)),
               columns =['title', 'description', 'link'])
        
        display(df)
        
        # Store to csv file
        df.to_csv('ws.csv', sep=',', index=False,header=True)
        
        print('Web Scraping Successful!')

# %%
keyword = input('Enter Keyword to be searched: ').lower()
w_api = Weather_API(keyword)
w_api.news_api()

location = input('Enter Location: ').lower()
ws = Web_Scraping('India')
ws.selenium_webdriver()
# Out:
# Enter Keyword to be searched: goa
# API call successful!
# {
#     "articles": [
#         {
#             "author": "Pavneet Singh Chadha",
#             "content": "Spiritual circuits, temple trails, flights to prominent destinations in tier 2 cities, a structure to honour Lord Parshuram, promoting local festivals and marketing campaigns to document Goa\u2019s cultur\u2026 [+2863 chars]",
#             "description": "Tourism department officials said Goa is largely perceived as a \"sun, sand, sea\" destination and the government has lately been working on plans to add another layer to that perception and encourage tourists to explore Goa \"beyond the beaches\".",
#             "publishedAt": "2023-10-05T09:02:14Z",
#             "source": {
#                 "id": null,
#                 "name": "The Indian Express"
#             },
#             "title": "Sun, sand and spirituality \u2013 how Goa plans to woo a different type of tourist",
#             "url": "https://indianexpress.com/article/india/sun-sand-spirituality-goa-plans-tourist-8969643/",
#             "urlToImage": "https://images.indianexpress.com/2023/10/Goa-tourist.jpg"
#         },
#         {
#             "author": "Entertainment Desk",
#             "content": "In his early days in the Hindi film industry, Amitabh Bachchan got a lot of support from veteran actor Mehmood and in a recent chat, the late comedian\u2019s brother Anwar Ali opened up about the time whe\u2026 [+2064 chars]",
#             "description": "Mehmood's brother Anwar Ali recalled the time when Amitabh Bachchan lived with them for two years and how he landed the lead part in Bombay to Goa.",
#             "publishedAt": "2023-10-12T07:41:41Z",
#             "source": {
#                 "id": null,
#                 "name": "The Indian Express"
#             },
#             "title": "How Amitabh Bachchan found a home in Mehmood\u2019s mansion for 2 years, would ride around in Anwar Ali\u2019s Jaguar during struggle",
#             "url": "https://indianexpress.com/article/entertainment/bollywood/how-amitabh-bachchan-found-a-home-in-mehmoods-mansion-for-2-years-would-ride-around-in-anwar-alis-jaguar-during-struggle-8979461/",
#             "urlToImage": "https://images.indianexpress.com/2023/10/amitabh-bachchan-mehmood.jpg"
#         },
#         {
#             "author": "Pavneet Singh Chadha",
#             "content": "Goa Minister for Archives and Archaeology Subhash Phal Dessai on Tuesday said that while the Portuguese, who ruled Goa for more than 400 years, had committed atrocities against Goans, they had done a\u2026 [+2202 chars]",
#             "description": "Emphasising the importance of preserving and sharing Goa's rich history, he said, \u201cPeople should know our heritage and history and the documentation will help to keep it alive and build our future.",
#             "publishedAt": "2023-09-26T18:05:25Z",
#             "source": {
#                 "id": null,
#                 "name": "The Indian Express"
#             },
#             "title": "Goa minister: Portuguese committed atrocities, but did a good thing by preserving documents",
#             "url": "https://indianexpress.com/article/india/goa-minister-portuguese-committed-atrocities-but-did-a-good-thing-by-preserving-documents-8957701/",
#             "urlToImage": "https://images.indianexpress.com/2023/09/Goa-5.jpg"
#         },
#         {
#             "author": "Pavneet Singh Chadha",
#             "content": "A day after being appointed as AAP\u2019s state vice president in the new organisational structure, Pratima Coutinho quit the party Wednesday citing \u201cpersonal and professional\u201d reasons. In June this year,\u2026 [+2620 chars]",
#             "description": "In a letter to the party's national convener Arvind Kejriwal, Coutinho said it was time for her to explore other horizons and pursue other avenues in her career and personal life.",
#             "publishedAt": "2023-09-28T04:10:12Z",
#             "source": {
#                 "id": null,
#                 "name": "The Indian Express"
#             },
#             "title": "Day after reshuffle, AAP Goa vice president Pratima Coutinho quits party",
#             "url": "https://indianexpress.com/article/cities/goa/day-after-reshuffle-aap-goa-vice-president-pratima-coutinho-quits-party-8959538/",
#             "urlToImage": "https://images.indianexpress.com/2023/09/AAP-Goa-vice-president.jpg"
#         },
#         {
#             "author": null,
#             "content": "Cest la face obscure du nomadisme num\u00e9rique quexp\u00e9rimente Goa. Cet \u00c9tat indien qui donne sur la mer dArabie, connu pour ses plages idylliques, son mode de vie d\u00e9contract\u00e9 et son h\u00e9ritage colonial por\u2026 [+2412 chars]",
#             "description": "Les autorit\u00e9s locales avaient mis\u00e9 sur la venue de travailleurs \u00e9trangers pour redynamiser la r\u00e9gion. Mais l\u2019installation des t\u00e9l\u00e9travailleurs a entra\u00een\u00e9 une hausse des loyers sans r\u00e9soudre le probl\u00e8me du ch\u00f4mage, d\u00e9taille \u201cRest of the World\u201d.",
#             "publishedAt": "2023-10-06T07:06:02Z",
#             "source": {
#                 "id": null,
#                 "name": "Courrier International"
#             },
#             "title": "L\u2019\u00c9tat indien de Goa submerg\u00e9 par les nomades num\u00e9riques",
#             "url": "https://www.courrierinternational.com/article/tensions-l-etat-indien-de-goa-submerge-par-les-nomades-numeriques",
#             "urlToImage": "https://focus.courrierinternational.com/2023/09/18/0/0/1280/960/1200/630/60/0/aa97ac0_1695039925656-sand-1323910-1280.jpg"
#         },
#         {
#             "author": "Et Al. Desk",
#             "content": "India, a land of incredible diversity and rich cultural heritage, is rapidly emerging as a top destination for sustainable travel experiences. Travellers are increasingly seeking eco-friendly options\u2026 [+3632 chars]",
#             "description": "India offers a plethora of sustainable travel experiences that not only immerse you in its natural beauty and vibrant culture but also contribute to the preservation of its unique ecosystems",
#             "publishedAt": "2023-09-26T11:17:32Z",
#             "source": {
#                 "id": null,
#                 "name": "The Indian Express"
#             },
#             "title": "World Tourism Day: Sustainable Travel Experiences To Bookmark",
#             "url": "https://indianexpress.com/article/et-al-express-curated/world-tourism-day-sustainable-travel-experiences-to-bookmark-before-the-year-ends-8956583/",
#             "urlToImage": "https://images.indianexpress.com/2023/09/wtd-horizontal.png"
#         },
#         {
#             "author": "ugc",
#             "content": "Saint Francis Xaviers name is remembered throughout Asia, from India to Japan, where he was the first to introduce Christianity. Born in 1506 in the Kingdom of Navarre, he co-founded the Jesuit Order\u2026 [+1535 chars]",
#             "description": "Saint Francis Xavier\u2019s name is remembered throughout Asia, from India to Japan, where he was the first to introduce Christianity. Born in 1506 in the Kingdom of Navarre, he co-founded the Jesuit Order in 1540 with Ignatius of Loyola and traveled the world as \u2026",
#             "publishedAt": "2023-09-21T20:00:00Z",
#             "source": {
#                 "id": null,
#                 "name": "Atlas Obscura"
#             },
#             "title": "Francis Xavier Statue in Malacca, Malaysia",
#             "url": "https://www.atlasobscura.com/places/francis-xavier-statue-malacca",
#             "urlToImage": "https://img.atlasobscura.com/foXAyRWZ4Nx1ZW9uqj-HxvtVaDSWWGHMr2hG6JY4VIk/rt:fit/w:600/q:81/sm:1/scp:1/ar:1/aHR0cHM6Ly9hdGxh/cy1kZXYuczMuYW1h/em9uYXdzLmNvbS91/cGxvYWRzL3BsYWNl/X2ltYWdlcy8xZTgy/MmZlMi1kYzhiLTQy/ZTUtYWUwMi0yM2Ex/YjhmZDc4NzQzNzY2/MDgzODM1YjNhYzI5/ZTdfNEIyNEU3Qjgt/RTZERi00NzkxLTg1/RTUtRDUyOEVGRERD/OTMxLmpwZWc.jpg"
#         },
#         {
#             "author": "ted.litchfield@futurenet.com (Ted Litchfield)",
#             "content": "\"In Baldur's Gate 3, when you wear shoes with metal on them, we wanted them to have a unique sound layer of metal clanks,\" explains one of Baldur's Gate 3's sound designers, Glenn Goa, in a video dem\u2026 [+1994 chars]",
#             "description": "Um, excuse me, they're called sabatons?",
#             "publishedAt": "2023-10-06T21:11:58Z",
#             "source": {
#                 "id": null,
#                 "name": "PC Gamer"
#             },
#             "title": "One of Baldur's Gate 3's sound designers studied blacksmithing and made a pair of metal shoes just to record armor clanking noises for the game",
#             "url": "https://www.pcgamer.com/one-of-baldurs-gate-3s-sound-designers-studied-blacksmithing-and-made-a-pair-of-metal-shoes-just-to-record-armor-clanking-noises-for-the-game/",
#             "urlToImage": "https://cdn.mos.cms.futurecdn.net/R8Mssez3jK9Yq6ZQs7q7fC-1200-80.jpg"
#         },
#         {
#             "author": "Saori Almeida",
#             "content": "A sonoriza\u00e7\u00e3o \u00e9 um dos fatores importantes para manter o n\u00edvel de imers\u00e3o de um jogo, e a equipe de Baldur\u2019s Gate 3foi al\u00e9m do esperado para entregar uma boa experi\u00eancia aos jogadores. Um dos designe\u2026 [+1245 chars]",
#             "description": "Equipe queria que os jogadores tivessem uma experi\u00eancia sonora \u00fanica enquanto usassem armaduras \nThe post Designer de Baldur\u2019s Gate 3 aprendeu ferraria para criar sons do jogo appeared first on Jovem Nerd.",
#             "publishedAt": "2023-10-10T14:11:35Z",
#             "source": {
#                 "id": null,
#                 "name": "Jovemnerd.com.br"
#             },
#             "title": "Designer de Baldur\u2019s Gate 3 aprendeu ferraria para criar sons do jogo",
#             "url": "https://jovemnerd.com.br/nerdbunker/designer-de-baldurs-gate-3-aprendeu-ferraria-para-criar-sons-do-jogo/",
#             "urlToImage": "https://uploads.jovemnerd.com.br/wp-content/uploads/2023/10/bg3_laezel_2__kz1w0513.jpg"
#         },
#         {
#             "author": "Anjishnu Das",
#             "content": "Last week, West Bengal announced a Rs 40,000 salary hike for MLAs, who now each earn Rs 1.21 lakh a month. Before the hike, the state had the third lowest salary for MLAs in the country. Now, its the\u2026 [+4087 chars]",
#             "description": "As West Bengal gives its MLAs a Rs 40,000 monthly raise, data shows that on an average, legislators across states earn Rs 1.5 lakh a month. An MP, in contrast, earns Rs 2.7 lakh monthly.",
#             "publishedAt": "2023-09-14T09:14:43Z",
#             "source": {
#                 "id": null,
#                 "name": "The Indian Express"
#             },
#             "title": "Jharkhand top at Rs 2.9 lakh, Kerala bottom at Rs 70,000: MLA salaries, and surprises",
#             "url": "https://indianexpress.com/article/political-pulse/jharkhand-mla-salaries-surprises-8939761/",
#             "urlToImage": "https://images.indianexpress.com/2023/09/mla-salaries-1200.jpg"
#         },
#         {
#             "author": "ugc",
#             "content": "Parvati Hill has historically been an essential part of Punes culture and heritage. The hill is known for its iconic temple complex, museum, memorial, and cave.\r\nOn the top of the hill, between the D\u2026 [+997 chars]",
#             "description": "Parvati Hill has historically been an essential part of Pune\u2019s culture and heritage. The hill is known for its iconic temple complex, museum, memorial, and cave.\nOn the top of the hill, between the Devdeveshwar Temple and the Peshwa Museum, in a beautiful gar\u2026",
#             "publishedAt": "2023-09-18T18:00:00Z",
#             "source": {
#                 "id": null,
#                 "name": "Atlas Obscura"
#             },
#             "title": "Parvati Hill Chapha Tree in Pune, India",
#             "url": "https://www.atlasobscura.com/places/parvati-hill-chapha-tree",
#             "urlToImage": "https://img.atlasobscura.com/DolzF-_wQCVflk1mgUZi-i0LEz2Qrc9reJRbR6WRwEY/rt:fit/w:600/c:1022:681:nowe:0:0/q:81/sm:1/scp:1/ar:1/aHR0cHM6Ly9hdGxh/cy1kZXYuczMuYW1h/em9uYXdzLmNvbS91/cGxvYWRzL3BsYWNl/X2ltYWdlcy81ZjY1/ZmUzMy02MzU0LTQw/MGEtYTRiNy05OTZm/ZDNkNWU3NTA1NzVi/YzRiNDNlZTQ3ODk1/ODdfNC5qcGc.jpg"
#         },
#         {
#             "author": "Glenn Reynolds",
#             "content": "InstaPundit is a participant in the Amazon Services LLC Associates Program, an affiliate advertising program designed to provide a\r\n means for sites to earn advertising fees by advertising and linkin\u2026 [+15 chars]",
#             "description": "FIGHT THE POWER: CRPA, SAF, GOA and Others Jointly File Federal Lawsuit Challenging California\u2019s Carry Restriction Law.",
#             "publishedAt": "2023-09-27T20:00:44Z",
#             "source": {
#                 "id": null,
#                 "name": "Instapundit.com"
#             },
#             "title": "FIGHT THE POWER: CRPA, SAF, GOA and Others Jointly File Federal Lawsuit Challenging California\u2019s",
#             "url": "https://instapundit.com/607835/",
#             "urlToImage": "https://instapundit.com/wp-content/themes/instapundit/images/opengraph-default.png"
#         },
#         {
#             "author": null,
#             "content": "[Removed]",
#             "description": "[Removed]",
#             "publishedAt": "1970-01-01T00:00:00Z",
#             "source": {
#                 "id": null,
#                 "name": "[Removed]"
#             },
#             "title": "[Removed]",
#             "url": "https://removed.com",
#             "urlToImage": null
#         },
#         {
#             "author": "Skift",
#             "content": "The tourism sector is booming in India, and companies have jobs to fill: There was 44% growth in hiring demand in the industry in August, according to latest data by recruitment platform foundit (for\u2026 [+7933 chars]",
#             "description": "Smaller cities in India are playing a significant role in the resurgence of jobs in the travel and tourism sector, indicating a broader geographic distribution of tourism opportunities. -Peden Doma Bhutia",
#             "publishedAt": "2023-10-04T03:00:00Z",
#             "source": {
#                 "id": null,
#                 "name": "Skift"
#             },
#             "title": "Skift India Report: Tourism Job Postings Surge",
#             "url": "https://skift.com/2023/10/03/skift-india-report-tourism-job-postings-surge/",
#             "urlToImage": "https://skift.com/wp-content/uploads/2023/10/pexels-photo-5668858-e1696333464634.jpeg"
#         },
#         {
#             "author": "AWR Hawkins, AWR Hawkins",
#             "content": "Gun Owners of America (GOA) secured a temporary restraining order Wednesday against New Mexico Gov. Michelle Lujan Grisham\u2019s (D) ban on concealed carry.\r\nGOA announced the decision via X:\r\nBREAKING\r\n\u2026 [+1771 chars]",
#             "description": "Gun Owners of America secured a temporary restraining order against New Mexico Gov. Michelle Lujan Grisham's (D) ban on concealed carry.",
#             "publishedAt": "2023-09-13T22:13:45Z",
#             "source": {
#                 "id": "breitbart-news",
#                 "name": "Breitbart News"
#             },
#             "title": "Smacked Down: Temporary Restraining Order Issued Against NM Gov's Concealed Carry Ban",
#             "url": "https://www.breitbart.com/2nd-amendment/2023/09/13/smacked-down-temporary-restraining-order-issued-against-nm-govs-concealed-carry-ban/",
#             "urlToImage": "https://media.breitbart.com/media/2023/09/Michelle-Lujan-Grisham-640x335.jpg"
#         },
#         {
#             "author": "Mini Ribeiro",
#             "content": "Vinayak Chaturthi or Ganeshotsav, the 10-day festival is heralded by the installation of Ganesha's clay idols in homes and publicly in elaborate pandals for community celebrations.\r\nOn Anant Chaturda\u2026 [+6634 chars]",
#             "description": "Ganesh Chaturthi, in the Bhadrapada month of the Hindu calendar, marks the elephant-God, Lord Ganesha\u00e2\u0080\u0099s birthday and is celebrated with fervour in several parts of India, especially in Maharashtra, Goa, Karnataka and Andhra Pradesh.",
#             "publishedAt": "2023-09-17T15:22:55Z",
#             "source": {
#                 "id": null,
#                 "name": "Moneycontrol"
#             },
#             "title": "9 places in India to visit and witness Ganesh Chaturthi at",
#             "url": "https://www.moneycontrol.com/news/trends/travel/9-places-in-india-to-visit-and-witness-ganesh-chaturthi-at-11383721.html",
#             "urlToImage": "https://images.moneycontrol.com/static-mcnews/2023/09/Ganesh_visarjan_surat_2009-770x433.jpg"
#         },
#         {
#             "author": "Christina Nellemann",
#             "content": "From living in a tiny house to running an Airbnb tiny house business, the family behind Simplify Further has walked the walk.\r\nSimplify Further builds elegant tiny homes with affordability and versat\u2026 [+1774 chars]",
#             "description": "From living in a tiny house to running an Airbnb tiny house business, the family behind Simplify Further has walked the walk. Simplify Further builds elegant tiny homes with affordability and versatility in mind. Located in Lake Butler, Florida, Simplify Furt\u2026",
#             "publishedAt": "2023-09-25T10:00:35Z",
#             "source": {
#                 "id": null,
#                 "name": "Tinyhouseblog.com"
#             },
#             "title": "Simplify Further\u2019s Bohemian Tiny Homes for Under $50,000",
#             "url": "https://tinyhouseblog.com/stick-built/simplifyfurther/",
#             "urlToImage": "https://150057231.v2.pressablecdn.com/wp-content/uploads/2023/09/SimplifyFurther-Tulsi-TinyHome.jpg"
#         },
#         {
#             "author": "Maryam Farooqui",
#             "content": "The October 2 holiday on account of Gandhi Jayanti\u00a0falling on a Monday has given another extended weekend opportunity to travellers, resulting in a more than 40 percent spike in flight searches.\r\nMaj\u2026 [+3430 chars]",
#             "description": "In addition to the World Cup, the long weekends and festivals in October, such as Gandhi Jayanti and Durga Puja, are further contributing to the rise in travel, said travel firms.",
#             "publishedAt": "2023-09-30T09:19:34Z",
#             "source": {
#                 "id": null,
#                 "name": "Moneycontrol"
#             },
#             "title": "October 2 long weekend records over 40% surge in flight searches, hotel occupancy at 90%",
#             "url": "https://www.moneycontrol.com/news/trends/travel/october-2-long-weekend-records-over-40-surge-in-flight-searches-hotel-occupancy-at-90-11455941.html",
#             "urlToImage": "https://images.moneycontrol.com/static-mcnews/2022/09/air-travel-770x433.jpg"
#         },
#         {
#             "author": "Skift",
#             "content": "We are thrilled to announce a new event coming next year, the Skift India Summitin Delhi-NCR, happening March 20-21, 2024. This follows the successful launch of our India newsletter, Skift India Repo\u2026 [+7397 chars]",
#             "description": "Slowdown? Boeing instead sees the boom rolling on \u2014 spurred by a growing middle class with high disposable income, coupled with the government\u2019s focus on building additional infrastructure to support air travel and connectivity. -Amrita Ghosh",
#             "publishedAt": "2023-09-14T03:00:00Z",
#             "source": {
#                 "id": null,
#                 "name": "Skift"
#             },
#             "title": "Skift India Report: Our First India Summit",
#             "url": "https://skift.com/2023/09/13/skift-india-report-boeing-sees-no-slowdown-with-strong-airline-profits/",
#             "urlToImage": "https://skift.com/wp-content/uploads/2023/05/india-flights-lineup.jpg"
#         },
#         {
#             "author": "Skift",
#             "content": "Low-cost carrier Indigo has now introduced a distance-based fuel charge on domestic and international routes.\r\nWhy This Fare Hike? The decision follows the significant increase in Aviation Turbine Fu\u2026 [+8275 chars]",
#             "description": "India's largest airline has introduced a distance-dependent fuel surcharge and other airlines are expected to follow suit. Doubt that will have much effect on India's consistently growing aviation sector. -Peden Doma Bhutia",
#             "publishedAt": "2023-10-10T03:00:00Z",
#             "source": {
#                 "id": null,
#                 "name": "Skift"
#             },
#             "title": "Skift India Report: Airfares Set to Go Up as Indigo Levies Fuel Charge",
#             "url": "https://skift.com/2023/10/09/indigo-introduces-distance-based-fuel-charge-amid-rising-atf-prices/",
#             "urlToImage": "https://skift.com/wp-content/uploads/2023/06/Indigo.jpg"
#         },
#         {
#             "author": "Zac Ntim",
#             "content": "EXCLUSIVE: The London Indian Film Festival is expanding.\u00a0\r\nWith its 2023 edition, running October 25 to November 4, the festival will, for the first time, run simultaneously across five cities: Londo\u2026 [+2730 chars]",
#             "description": "EXCLUSIVE: The London Indian Film Festival is expanding.\u00a0 With its 2023 edition, running October 25 to November 4, the festival will, for the first time, run simultaneously across five cities: London, Manchester, Birmingham, Bradford and Leeds. The festival w\u2026",
#             "publishedAt": "2023-09-29T10:16:27Z",
#             "source": {
#                 "id": null,
#                 "name": "Deadline"
#             },
#             "title": "London Indian Film Festival Sets UK-Wide Expansion With 2023 Edition",
#             "url": "https://deadline.com/2023/09/london-indian-film-festival-2023-edition-uk-1235559589/",
#             "urlToImage": "https://deadline.com/wp-content/uploads/2023/09/5-BerlinBerlin-with-mandate.jpg?w=1024"
#         },
#         {
#             "author": "Parimal A Dabhi",
#             "content": "Flagging increasing incidents of custodial death in Gujarat as a matter of great public concern, the Gujarat State Law Commission (SLC) has recently submitted a report to the state government making \u2026 [+3133 chars]",
#             "description": "The SLC also cited the chapter on custodial crimes and complaints against police personnel from the 'NCRB - Crimes in India: 2021' report.",
#             "publishedAt": "2023-09-28T22:29:09Z",
#             "source": {
#                 "id": null,
#                 "name": "The Indian Express"
#             },
#             "title": "Matter of great concern: Gujarat law panel flags custodial deaths",
#             "url": "https://indianexpress.com/article/cities/gandhinagar/matter-of-great-concern-gujarat-law-panel-flags-custodial-deaths-8960933/",
#             "urlToImage": "https://images.indianexpress.com/2023/09/jail-7.jpg"
#         },
#         {
#             "author": "Express News Service",
#             "content": "A special court on Monday granted bail to alleged bookie Anil Jaisinghani, arrested in March for the alleged blackmail and extortion of Amruta Fadnavis, wife of Maharashtra Deputy Chief Minister Deve\u2026 [+2808 chars]",
#             "description": "On Monday, special judge DD Almale granted Jaisinghani bail on execution of surety of Rs 50,000 in connection with the case filed by Malabar Hill police station on charges, including extortion, criminal conspiracy and relevant sections of the Prevention of Co\u2026",
#             "publishedAt": "2023-09-18T14:22:16Z",
#             "source": {
#                 "id": null,
#                 "name": "The Indian Express"
#             },
#             "title": "Bookie Jaisinghani gets bail in Amruta Fadnavis extortion case",
#             "url": "https://indianexpress.com/article/cities/mumbai/bookie-jaisinghani-gets-bail-in-amruta-fadnavis-extortion-case-8945706/",
#             "urlToImage": "https://images.indianexpress.com/2023/06/anil-jaisinghani.jpg"
#         },
#         {
#             "author": "Anju Agnihotri Chaba",
#             "content": "Nature enthusiasts in Punjab have good news to cheer. The states Forest Department has recently launched the Chohal Eco Tourism Project (Nature Retreat Chohal) in the Hoshiarpur district which offers\u2026 [+2699 chars]",
#             "description": "Nature lovers can stay in huts, immerse themselves in the beauty of the natural environment, and the Chohal reservoir and experience the local culture and cuisines.",
#             "publishedAt": "2023-09-14T10:59:59Z",
#             "source": {
#                 "id": null,
#                 "name": "The Indian Express"
#             },
#             "title": "Chohal ecotourism project, a retreat for wildlife enthusiasts in Punjab",
#             "url": "https://indianexpress.com/article/cities/chandigarh/chohal-ecotourism-project-a-retreat-for-wildlife-enthusiasts-in-punjab-8939897/",
#             "urlToImage": "https://images.indianexpress.com/2023/09/chohal-3.jpeg"
#         },
#         {
#             "author": "Malavika Prasad",
#             "content": "The Delhi High Court Wednesday ordered that both Humans of Bombay and People of India will refrain from using each others copyrighted work such as commissioned images, literary works, original pieces\u2026 [+2654 chars]",
#             "description": "POI\u2019s counsel said that these four elements would identically apply to POI and HOB be cautioned against imitating POI's work as well.",
#             "publishedAt": "2023-10-11T13:27:04Z",
#             "source": {
#                 "id": null,
#                 "name": "The Indian Express"
#             },
#             "title": "Humans of Bombay vs People of India: HC says platforms can\u2019t use each other\u2019s copyrighted work",
#             "url": "https://indianexpress.com/article/cities/delhi/humans-of-bombay-vs-people-of-india-hc-platforms-copyrighted-work-8978517/",
#             "urlToImage": "https://images.indianexpress.com/2023/10/delhi-hc-2.jpg"
#         },
#         {
#             "author": "Ethan Huff",
#             "content": "In response to the recent attacks by Hamas, Israel has reportedly relaxed its strict gun control laws, a move that Gun Owners of America (GOA) is lauding as an example of why Americans need the Secon\u2026 [+3554 chars]",
#             "description": "In response to the recent attacks by Hamas, Israel has reportedly relaxed its strict gun control laws, a move that Gun Owners of America (GOA) is lauding as an example of why Americans need the Second Amendment. For matters of self-defense, Israel appears to \u2026",
#             "publishedAt": "2023-10-12T06:00:00Z",
#             "source": {
#                 "id": null,
#                 "name": "Naturalnews.com"
#             },
#             "title": "2A WORKS! Gun Owners of America says horrific situation in Israel shows why Americans were afforded the right to \u201cweapons of war\u201d \u00e2\u0080\u0093 for SELF-DEFENSE",
#             "url": "https://www.naturalnews.com/2023-10-12-israel-hamas-america-weapons-war-second-amendment.html",
#             "urlToImage": "https://www.naturalnews.com/wp-content/uploads/sites/91/2023/10/Second-Amendment-Guns-2.jpg"
#         },
#         {
#             "author": null,
#             "content": "[Removed]",
#             "description": "[Removed]",
#             "publishedAt": "1970-01-01T00:00:00Z",
#             "source": {
#                 "id": null,
#                 "name": "[Removed]"
#             },
#             "title": "[Removed]",
#             "url": "https://removed.com",
#             "urlToImage": null
#         },
#         {
#             "author": null,
#             "content": "Isaac Price scored a 90th-minute winner against Club Brugge on 8 October for his first goa with Standard Liege\r\n<table><tr><th>Euro 2024 qualifying: Northern Ireland v San Marino</th></tr>\r\n<tr><td>V\u2026 [+4239 chars]",
#             "description": "After 13 years at Everton, Northern Ireland midfielder Isaac Price is thriving after deciding to move to Standard Liege in Belgium.",
#             "publishedAt": "2023-10-12T08:20:31Z",
#             "source": {
#                 "id": "bbc-news",
#                 "name": "BBC News"
#             },
#             "title": "Isaac Price: 'Different but great' - NI youngster who left Everton for Belgium",
#             "url": "https://www.bbc.co.uk/sport/football/67080788",
#             "urlToImage": "https://ichef.bbci.co.uk/live-experience/cps/624/cpsprodpb/14DB/production/_131393350_pe_00939120.jpg"
#         },
#         {
#             "author": "katakori",
#             "content": "9Baldurs Gate III\r\nBaldurs Gate IIIGlenn Gullskjegg Goa8Glenn Gullskjegg Goa\r\nGlenn G. GoaBaldurs Gate III",
#             "description": "\u5148\u65e5\u3001\u50ad\u5175\u306e\u5916\u89b3\u5909\u66f4\u6a5f\u80fd\u3092\u5c0e\u5165\u3059\u308b\u7b2c9\u5f3e\u30db\u30c3\u30c8\u30d5\u30a3\u30c3\u30af\u30b9\u304c\u914d\u4fe1\u3055\u308c\u305f\u300cBaldur\u2019s Gate III\u300d\u3067\u3059\u304c\u3001\u6765\u308b\u65e5\u672c\u8a9e\u7248\u306e\u767a\u58f2\u306b\u671f\u5f85\u304c\u639b\u304b\u308b\u306a\u304b\u3001\u65b0\u305f\u306b\u672c\u4f5c\u3067\u91d1\u5c5e\u88fd\u306e\u9a0e\u58eb\u7528\u30d6\u30fc\u30c4\uff08\u30b5\u30d0\u30c8\u30f3\uff09\u3092\u88c5\u5099\u3057\u305f\u969b\u306b\u9cf4\u308b\u6b69\u884c\u30b5 [\u2026]",
#             "publishedAt": "2023-10-09T02:41:08Z",
#             "source": {
#                 "id": null,
#                 "name": "Doope.jp"
#             },
#             "title": "\u300cBaldur\u2019s Gate III\u300d\u306e\u30b5\u30a6\u30f3\u30c9\u30c7\u30b6\u30a4\u30ca\u30fc\u304c\u6b69\u884c\u97f3\u306e\u53ce\u9332\u6620\u50cf\u3092\u516c\u958b\u3001\u5b9f\u969b\u306b\u935b\u51b6\u3092\u5b66\u3093\u3067\u9a0e\u58eb\u306e\u30d7\u30ec\u30fc\u30c8\u9774\u3092\u81ea\u4f5c",
#             "url": "https://doope.jp/2023/10140219.html",
#             "urlToImage": "https://doope.jp/media/20q2/img1807_01.jpg"
#         },
#         {
#             "author": "Samuel Forey",
#             "content": "Une vid\u00e9o publi\u00e9e sur la cha\u00eene Telegram le 9\u00a0octobre\u00a02023, apr\u00e8s lattaque de la rave Supernova par le Hamas, pr\u00e8s du kibboutz R\u00e9\u00efm dans le d\u00e9sert du N\u00e9guev, dans le sud dIsra\u00ebl, le 8\u00a0octobre\u00a02023. A\u2026 [+2934 chars]",
#             "description": "Un festival de musique \u00e9lectronique se tenait encore samedi au petit matin, quand l\u2019attaque du Hamas a commenc\u00e9. Des survivants ont racont\u00e9 au \u00ab\u00a0Monde\u00a0\u00bb comment les participants se sont retrouv\u00e9s pris au pi\u00e8ge. Selon les premi\u00e8res estimations, les festivalier\u2026",
#             "publishedAt": "2023-10-10T03:48:08Z",
#             "source": {
#                 "id": "le-monde",
#                 "name": "Le Monde"
#             },
#             "title": "Des rescap\u00e9s du massacre de la rave-party, en Isra\u00ebl, t\u00e9moignent\u00a0: \u00ab\u00a0On ne voyait pas comment s\u2019en tirer\u00a0\u00bb",
#             "url": "https://www.lemonde.fr/international/article/2023/10/10/des-rescapes-du-massacre-de-la-rave-party-en-israel-temoignent-on-ne-voyait-pas-comment-s-en-tirer_6193473_3210.html",
#             "urlToImage": "https://img.lemde.fr/2023/10/09/0/165/2169/1446/1440/960/60/0/1158aaf_5528669-01-06.jpg"
#         },
#         {
#             "author": "VnExpress",
#             "content": "IranCV Iran chy theo xe v\u00e0 x\u00f4ng v\u00e0o kh\u00e1ch sn ca Al Nassr c nh\u00ecn thy Cristiano Ronaldo, khi anh n th \u00f4 Tehran chun b cho trn v\u00f2ng bng AFC Champions League vi Persepolis.Theo video ng tr\u00ean mng x\u00e3 hi X,\u2026 [+2055 chars]",
#             "description": "Iran- C\u0110V Iran ch\u1ea1y theo xe v\u00e0 x\u00f4ng v\u00e0o kh\u00e1ch s\u1ea1n c\u1ee7a Al Nassr \u0111\u1ec3 \u0111\u01b0\u1ee3c nh\u00ecn th\u1ea5y Cristiano Ronaldo, khi anh \u0111\u1ebfn th\u1ee7 \u0111\u00f4 Tehran \u0111\u1ec3 chu\u1ea9n b\u1ecb cho tr\u1eadn v\u00f2ng b\u1ea3ng AFC Champions League v\u1edbi Persepolis.",
#             "publishedAt": "2023-09-18T23:59:02Z",
#             "source": {
#                 "id": null,
#                 "name": "Vnexpress.net"
#             },
#             "title": "C\u0110V Iran ph\u00e1t cu\u1ed3ng khi ch\u00e0o \u0111\u00f3n Ronaldo",
#             "url": "https://vnexpress.net/cdv-iran-phat-cuong-khi-chao-don-ronaldo-4654698.html",
#             "urlToImage": "https://vcdn1-thethao.vnecdn.net/2023/09/19/newproject68-1695078611-169507-3339-5959-1695079019.jpg?w=1200&h=0&q=100&dpr=1&fit=crop&s=BdRhE9ShpaI-zQCBpRcK8w"
#         },
#         {
#             "author": "Christopher Elliott, Senior Contributor, \n Christopher Elliott, Senior Contributor\n https://www.forbes.com/sites/christopherelliott/",
#             "content": "Ha Long Bay, Vietnam, is one of the 24 top destinations for 2024.\r\ngetty\r\nAlmost everyone went somewhere this year, but there are still places to go. Lots of places. So what are the best destinations\u2026 [+18919 chars]",
#             "description": "Almost everyone went somewhere this year, but there are still places to go. Lots of places. So what are the best destinations for travel in 2024?",
#             "publishedAt": "2023-10-01T05:05:45Z",
#             "source": {
#                 "id": null,
#                 "name": "Forbes"
#             },
#             "title": "You\u2019ve Got To See This! The 24 Best Places To Travel In 2024",
#             "url": "https://www.forbes.com/sites/christopherelliott/2023/10/01/youve-got-to-see-this-the-24-best-places-to-travel-in-2024/",
#             "urlToImage": "https://imageio.forbes.com/specials-images/imageserve/65188b0893e4c635f7ae5ae1/0x0.jpg?format=jpg&width=1200"
#         },
#         {
#             "author": "Rishika  Sadam",
#             "content": "By Rishika Sadam\r\nHYDERABAD, India (Reuters) -India's Goa state has warned the local unit of Abbott Laboratories it plans to suspend the manufacturing license of its popular antacid medicine after in\u2026 [+2938 chars]",
#             "description": "HYDERABAD, India (Reuters) -India's Goa state has warned the local unit of Abbott Laboratories it plans to suspend the manufacturing license of its popular...",
#             "publishedAt": "2023-09-14T11:14:39Z",
#             "source": {
#                 "id": null,
#                 "name": "Yahoo Entertainment"
#             },
#             "title": "Goa state warns Abbott India on antacid Digene license suspension",
#             "url": "https://sg.finance.yahoo.com/news/goa-state-warns-abbott-india-111439681.html",
#             "urlToImage": "https://media.zenfs.com/en/reuters.com/5f7f39977f6688793dd408d04bbbedea"
#         },
#         {
#             "author": "Rishika  Sadam",
#             "content": "By Rishika Sadam\r\nHYDERABAD, India (Reuters) -India's Goa state has warned the local unit of Abbott Laboratories it plans to suspend the manufacturing license of its popular antacid medicine after in\u2026 [+2938 chars]",
#             "description": "HYDERABAD, India (Reuters) -India's Goa state has warned the local unit of Abbott Laboratories it plans to suspend the manufacturing license of its popular...",
#             "publishedAt": "2023-09-14T11:14:39Z",
#             "source": {
#                 "id": null,
#                 "name": "Yahoo Entertainment"
#             },
#             "title": "Goa state warns Abbott India on antacid Digene license suspension",
#             "url": "https://finance.yahoo.com/news/goa-state-warns-abbott-india-111439537.html",
#             "urlToImage": "https://media.zenfs.com/en/reuters-finance.com/5f7f39977f6688793dd408d04bbbedea"
#         },
#         {
#             "author": "Skift",
#             "content": "Holiday Inn and Holiday Inn Express brands, together making up nearly 70% of InterContinental Hotels Group (IHG)s portfolio in India, are going to remain the driver of growth in the market, said the \u2026 [+6836 chars]",
#             "description": "At a time when India's aviation and hospitality sectors are riding high on domestic travel, IHG is positioned well to capitalize on market opportunities with its Essentials collection of brands. -Amrita Ghosh",
#             "publishedAt": "2023-09-13T03:00:00Z",
#             "source": {
#                 "id": null,
#                 "name": "Skift"
#             },
#             "title": "Skift India Report: Holiday Inn Brands to Drive IHG\u2019s Growth",
#             "url": "https://skift.com/2023/09/12/skift-india-report-holiday-inn-and-holiday-inn-express-brands-to-drive-ihgs-growth/",
#             "urlToImage": "https://skift.com/wp-content/uploads/2023/09/dr-vallabh-kulkarni-U-zLOaxbGt0-unsplash-1.jpg"
#         },
#         {
#             "author": "Express News Service",
#             "content": "Abhishek Banerjee with TMC leaders outside the Raj Bhavan in Kolkata, Monday. (Express Photo by Partha Paul)The Trinamool Congress (TMC) on Monday lifted its dharna outside Raj Bhavan in Kolkata on t\u2026 [+5461 chars]",
#             "description": "Abhishek threatens fresh stir from Nov 1 if there\u2019s no clarity on MGNREGA dues",
#             "publishedAt": "2023-10-10T00:29:31Z",
#             "source": {
#                 "id": null,
#                 "name": "The Indian Express"
#             },
#             "title": "TMC ends dharna as Governor assures to raise demands",
#             "url": "https://indianexpress.com/article/cities/kolkata/tmc-ends-dharna-as-governor-assures-to-raise-demands-8975639/",
#             "urlToImage": "https://images.indianexpress.com/2023/10/tmc-dhana.jpg"
#         },
#         {
#             "author": null,
#             "content": "JMDC\r\n3JMDC1JMDC1\r\nGoGoGoA Tour of GoGo\r\nA Tour of Go GoA Tour of Go \r\n A Tour of Go A Tour of Go A Tour of Go \r\n2\r\nGoGoDBsqlcORM\r\nMVC/\r\n /DDD\r\nJMDC1JMDC\r\nBook Club\r\nOKR\r\nObjectives and Key ResultsOK\u2026 [+112 chars]",
#             "description": "\u307f\u306a\u3055\u3093\u3001\u3053\u3093\u306b\u3061\u306f\uff01\u30d7\u30ed\u30c0\u30af\u30c8\u958b\u767a\u90e8\u306e\u897f\u539f\u3067\u3059\u3002 \u73fe\u5728\u3001JMDC\u304c\u4fdd\u6709\u3057\u3066\u3044\u308b\u533b\u7642\u30d3\u30c3\u30b0\u30c7\u30fc\u30bf\u3092\u6d3b\u7528\u3057\u3066\u751f\u6d3b\u8005\u3084\u533b\u7642\u306b\u65b0\u3057\u3044\u4fa1\u5024\u3092\u63d0\u4f9b\u3059\u308b\u65b0\u898f\u30d7\u30ed\u30c0\u30af\u30c8\u958b\u767a\u30c1\u30fc\u30e0\u306e\u30d0\u30c3\u30af\u30a8\u30f3\u30c9\u3092\u62c5\u5f53\u3057\u3066\u304a\u308a\u307e\u3059\u3002 \u79c1\u3054\u3068\u3067\u3059\u304c\u3001\u672a\u7d4c\u9a13\u304b\u3089\u30a8\u30f3\u30b8\u30cb\u30a2\u696d\u754c\u306b\u8ee2\u8077\u3057\u3066\u7d043\u5e74\u306b\u306a\u308a\u307e\u3059\u3002\u305d\u3057\u3066\u3001\u5148\u65e5JMDC\u306b\u5165\u793e\u3057\u3066\u3061\u3087\u3046\u30691\u5e74\u7d4c\u3061\u307e\u3057\u305f\u3002\u307e\u3060\u307e\u3060\u30a8\u30f3\u30b8\u30cb\u30a2\u3068\u3057\u3066\u306e\u7d4c\u9a13\u306f\u6d45\u3044\u3067\u3059\u304c\u3001\u79c1\u306a\u308a\u306bJMDC\u3067\u306e1\u5e74\u9593\u3092\u632f\u308a\u8fd4\u308a\u305f\u3044\u3068\u601d\u3044\u307e\u3059\u3002 \u5165\u793e\u5f53\u521d \u65b0\u898f\u30d7\u30ed\u30c0\u30af\u30c8\u958b\u767a\u306e\u30d0\u30c3\u30af\u30a8\u30f3\u30c9\u3067\u306fGo\u8a00\u8a9e\u3092\u63a1\u7528\u3057\u3066\u3044\u307e\u3059\u3002\u79c1\u306fGo\u8a00\u8a9e\u306f\u672a\u7d4c\u9a13\u3060\u3063\u305f\u305f\u2026",
#             "publishedAt": "2023-10-03T10:19:46Z",
#             "source": {
#                 "id": null,
#                 "name": "Jmdc.co.jp"
#             },
#             "title": "JMDC\u306b\u5165\u793e\u3057\u30661\u5e74\u7d4c\u3063\u305f\u306e\u3067\u632f\u308a\u8fd4\u3063\u3066\u307f\u305f - JMDC TECH BLOG",
#             "url": "https://techblog.jmdc.co.jp/entry/reflection/jmdc",
#             "urlToImage": "https://cdn-ak.f.st-hatena.com/images/fotolife/j/jmdc_snishihara/20230927/20230927114117.jpg"
#         },
#         {
#             "author": null,
#             "content": "Manchester United's sensational comeback win against Brentford must be a turning point for the Old Trafford club after a woeful start to the season, manager Erik ten Hag said.\r\nUnited recovered from \u2026 [+1658 chars]",
#             "description": "Manchester United's sensational comeback win against Brentford must be a turning point for the Old Trafford club after a woeful start to the season, manager Erik ten Hag said.United recovered from a goal down at home to secure a 2-1 victory in the Premier Lea\u2026",
#             "publishedAt": "2023-10-08T04:26:01Z",
#             "source": {
#                 "id": null,
#                 "name": "CNA"
#             },
#             "title": "Late recovery against Brentford 'has to be a turning point,' says United's Ten Hag",
#             "url": "https://www.channelnewsasia.com/sport/late-recovery-against-brentford-has-be-turning-point-says-uniteds-ten-hag-3829921",
#             "urlToImage": "https://onecms-res.cloudinary.com/image/upload/s--0YxmLROs--/fl_relative,g_south_east,l_one-cms:core:watermark:reuters,w_0.1/f_auto,q_auto/c_fill,g_auto,h_676,w_1200/v1/one-cms/core/2023-10-08t042601z_1_lynxmpej97016_rtroptp_3_soccer-champions-mun-gal-report.jpg?itok=cKR4-MK7"
#         },
#         {
#             "author": null,
#             "content": "Goa has been one of India's top goa-to destinations for tourists for decades on end. Other than the state's coastal beauty and blue waters, travellers love the seaside shacks for their range of food \u2026 [+1145 chars]",
#             "description": "The idea is to project the state's 'rich cuisine' to tourists whether they'd like to dip into it or not. While there is nothing wrong in giving tourists a taste of Goan food, what doesn't sound right is this 'mandatory' bit that sits rather unwell with the ch\u2026",
#             "publishedAt": "2023-10-09T17:31:35Z",
#             "source": {
#                 "id": "the-times-of-india",
#                 "name": "The Times of India"
#             },
#             "title": "Going going Goan in shack-ahari Goa",
#             "url": "https://economictimes.indiatimes.com/opinion/just-in-jest/going-going-goan-in-shack-ahari-goa/articleshow/104293106.cms",
#             "urlToImage": "https://img.etimg.com/thumb/msid-104293176,width-1200,height-630,imgsize-56800,overlay-economictimes/photo.jpg"
#         },
#         {
#             "author": "Moneycontrol News",
#             "content": "Singapore-listed and headquartered company CapitaLand Investment Limited (CLI) has launched operations for Phase I of the newly redeveloped International Tech Park Hyderabad (ITPH) with a 100 percent\u2026 [+1553 chars]",
#             "description": "The company added that it has also flagged off the development of a 40-megawatt (MW) data centre inside the tech park. The data centre will have a built-up area of 0.3 msf.",
#             "publishedAt": "2023-09-20T12:17:10Z",
#             "source": {
#                 "id": null,
#                 "name": "Moneycontrol"
#             },
#             "title": "CapitaLand launches Phase 1 of tech park in Hyderabad, to develop 4.9 million sq ft",
#             "url": "https://www.moneycontrol.com/news/business/real-estate/capitaland-launches-phase-1-of-tech-park-in-hyderabad-to-develop-4-9-million-sq-ft-11398351.html",
#             "urlToImage": "https://images.moneycontrol.com/static-mcnews/2023/09/WhatsApp-Image-2023-09-20-at-4.23.21-PM-581x435.jpeg"
#         },
#         {
#             "author": "Ghazal Ahmed",
#             "content": "This article looks at the 16 best places to retire in India. If you wish to skip our detailed analysis on spending retirement years in India, go to the 5 Best Places to Retire in India.\r\nUSA to India\u2026 [+13066 chars]",
#             "description": "This article looks at the 16 best places to retire in India. If you wish to skip our detailed analysis on spending retirement years in India, go to the 5...",
#             "publishedAt": "2023-09-23T11:50:09Z",
#             "source": {
#                 "id": null,
#                 "name": "Yahoo Entertainment"
#             },
#             "title": "16 Best Places to Retire in India",
#             "url": "https://finance.yahoo.com/news/16-best-places-retire-india-115009122.html",
#             "urlToImage": "https://s.yimg.com/ny/api/res/1.2/abzRIoaU3PSWh5U0MvLRnA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/insidermonkey.com/63d5c9bb41dd05804843133e16bb3b50"
#         },
#         {
#             "author": null,
#             "content": "Fethiye Belediyesinden yaplan a\u00e7klamada, \"Best places for a beach holiday in October\" balyla \"Ekim aynda plaj tatili i\u00e7in en iyi yerler\" listesini a\u00e7klayan The Times gazetesinin T\u00fcrkiye'den sadece Fe\u2026 [+509 chars]",
#             "description": "\u0130ngiliz The Times gazetesinin ekimde tatil i\u00e7in en iyi 10 adres listesinde Mu\u011fla'n\u0131n Fethiye il\u00e7esinin ikinci s\u0131rada g\u00f6sterildi\u011fi bildirildi. - Anadolu Ajans\u0131",
#             "publishedAt": "2023-10-03T13:05:25Z",
#             "source": {
#                 "id": null,
#                 "name": "Anadolu Agency"
#             },
#             "title": "The Times Gazetesi, ekimde en iyi 10 tatil yeri aras\u0131nda ikinci s\u0131rada Fethiye'yi g\u00f6sterdi",
#             "url": "https://www.aa.com.tr/tr/yasam/the-times-gazetesi-ekimde-en-iyi-10-tatil-yeri-arasinda-ikinci-sirada-fethiyeyi-gosterdi/3006869",
#             "urlToImage": "https://cdnuploads.aa.com.tr/uploads/Contents/2023/10/03/thumbs_b_c_1d366f13a94e0da14cfb1c35e0a1a6f0.jpg?v=160710"
#         },
#         {
#             "author": "Nitendra Pal Singh",
#             "content": "UPSC Essentials\u00a0brings to you its initiative of subject-wise quizzes. These quizzes are designed to help you revise some of the most important topics from the static part of the syllabus. Each day, w\u2026 [+6573 chars]",
#             "description": "Are you preparing for UPSC CSE Prelims 2024? Check your progress and revise your topics through this quiz on Environment, Geography, Science and Technology.",
#             "publishedAt": "2023-09-27T13:58:31Z",
#             "source": {
#                 "id": null,
#                 "name": "The Indian Express"
#             },
#             "title": "UPSC Essentials | Daily subject-wise quiz \u2014 Environment, Geography, Science and Technology (Week 25)",
#             "url": "https://indianexpress.com/article/upsc-current-affairs/upsc-essentials/upsc-essentials-daily-subject-wise-quiz-environment-geography-science-and-technology-week-25-8958895/",
#             "urlToImage": "https://images.indianexpress.com/2023/09/Untitled-design-2023-09-27T182130.046.jpg"
#         },
#         {
#             "author": null,
#             "content": "Homebrew Website Club is a growing world-wide network of meetups for everyone who wants to take back their web experience from social media silos, and own their online identities &amp; content, or ju\u2026 [+24841 chars]",
#             "description": "Comments",
#             "publishedAt": "2023-09-17T20:25:54Z",
#             "source": {
#                 "id": null,
#                 "name": "Indieweb.org"
#             },
#             "title": "Homebrew Website Club",
#             "url": "https://indieweb.org/Homebrew_Website_Club",
#             "urlToImage": null
#         },
#         {
#             "author": "Szymon Ku\u015b",
#             "content": "W Nowym Delhi postaw na 3* hotel Hari Piorko. Na miejscu znajdziesz komfortowo urzdzony pok\u00f3j z prywatn azienk i dostpem do WiFi.\r\nDowiedz si wicej o tym hotelu\r\nW Dehradun proponuj 4* hotel Saffron \u2026 [+375 chars]",
#             "description": "",
#             "publishedAt": "2023-09-28T16:20:00Z",
#             "source": {
#                 "id": null,
#                 "name": "Fly4free.pl"
#             },
#             "title": "Przygoda w Indiach: Nowe Delhi, Dehradun, Goa i Mumbaj w jednej podr\u00f3\u017cy z 5 polskich miast od 2939 PLN",
#             "url": "https://www.fly4free.pl/przygoda-w-indiach-nowe-delhi-dehradun-goa-i-mumbaj-w-jednej-podrozy-z-5-polskich-miast-od-2939-pln/",
#             "urlToImage": "https://f4fcdn.eu/wp-content/uploads/2022/03/Agra-Indie-Azja-scaled.jpg"
#         },
#         {
# ...
#             "description": "JSW Infrastructure IPO | This will be the first listing from the JSW Group since 2010 when it had listed its energy business separately.",
#             "publishedAt": "2023-09-27T07:52:29Z",
#             "source": {
#                 "id": null,
#                 "name": "Moneycontrol"
#             },
#             "title": "JSW Infrastructure IPO booked 8.5 times on final day, retail portion subscribed 7.5 times",
#             "url": "https://www.moneycontrol.com/news/business/ipo/jsw-infrastructure-ipo-booked-8-5-times-on-final-day-retail-portion-subscribed-7-5-times-11434661.html",
#             "urlToImage": "https://images.moneycontrol.com/static-mcnews/2023/09/JSW_InfrastructurePort-770x433.jpg"
#         },
#         {
#             "author": "Sidhartha",
#             "content": "FD Calculator\r\nWhen investing in a fixed deposit, the amount you deposit earns interest as per the prevailing...\r\nCalculate Now",
#             "description": "Goa has the lowest tax rates on liquor in India, resulting in cheaper prices compared to neighboring states like Karnataka and Maharashtra. An analysis by The International Spirits and Wines Association of India estimates that a bottle of spirits that costs R\u2026",
#             "publishedAt": "2023-09-24T19:24:50Z",
#             "source": {
#                 "id": "the-times-of-india",
#                 "name": "The Times of India"
#             },
#             "title": "Liquor price list: Goa cheapest, Karnataka tops",
#             "url": "https://timesofindia.indiatimes.com/business/india-business/liquor-price-list-goa-cheapest-karnataka-tops/articleshow/103914058.cms",
#             "urlToImage": "https://static.toiimg.com/thumb/msid-103914062,width-1070,height-580,imgsize-2132229,resizemode-75,overlay-toi_sw,pt-32,y_pad-40/photo.jpg"
#         },
#         {
#             "author": "Live from a Lounge",
#             "content": "British Airways and IndiGo announced a codeshare agreement, which would allow British Airways to add more stations to operate in India without adding more flights of their own. British Airways was al\u2026 [+3619 chars]",
#             "description": "IndiGo and British Airways have signed on for a new codeshare partnership which will allow BA to put its code on 6E flights in India. \nThe post British Airways enters codeshare agreement with IndiGo appeared first on Live from a Lounge.",
#             "publishedAt": "2023-09-22T02:08:07Z",
#             "source": {
#                 "id": null,
#                 "name": "Livefromalounge.com"
#             },
#             "title": "British Airways enters codeshare agreement with IndiGo",
#             "url": "https://livefromalounge.com/british-airways-enters-codeshare-agreement-with-indigo/",
#             "urlToImage": "https://livefromalounge.com/wp-content/uploads/2023/09/F6jXK3BXsAAGI56.jpeg"
#         },
#         {
#             "author": "Economy Class & Beyond",
#             "content": "It\u2019s time for more codeshare action, with British Airways and Indigo signing a codeshare agreement.\r\nBritish Airways and Indigo Crew \u2013 Image, British Airways\u00a0The move will boost connections between t\u2026 [+3805 chars]",
#             "description": "It\u2019s time for more codeshare action, with British Airways and Indigo signing a codeshare agreement. British Airways and Indigo Crew \u2013 Image, British Airways\u00a0 The move will boost connections between the UK and India. Through this partnership \u2013 which sees Briti\u2026",
#             "publishedAt": "2023-09-22T08:09:18Z",
#             "source": {
#                 "id": null,
#                 "name": "Boardingarea.com"
#             },
#             "title": "British Airways and Indigo sign a codeshare agreement",
#             "url": "https://economyclassandbeyond.boardingarea.com/2023/09/22/british-airways-and-indigo-sign-a-codeshare-agreement/",
#             "urlToImage": "https://economyclassandbeyond.boardingarea.com/wp-content/uploads/2023/09/britishairways_b767f1115b7ef-1-scaled.jpg"
#         },
#         {
#             "author": null,
#             "content": "Marathi News App: ? .\r\n<ul><li> , </li><li> - , , 65% </li><li> , ....</li><li> ; </li><li>43 - </li><li> , </li><li> : - ; </li><li> , , , </li><li>! , </li><li> , ...</li><li> '' , </li><li> , </li\u2026 [+66 chars]",
#             "description": "Mumbai Goa Highway : \u092e\u0941\u0902\u092c\u0908 \u0917\u094b\u0935\u093e \u092e\u0939\u093e\u092e\u093e\u0930\u094d\u0917\u093e\u0935\u0930\u0940\u0932 \u0938\u093e\u0935\u0930\u094d\u0921\u0947 \u0917\u093e\u0935\u093e\u091c\u0935\u0933 \u0905\u0902\u0927\u0947\u0930\u0940\u0939\u0942\u0928 \u0926\u0941\u091a\u093e\u0915\u0940\u0935\u0930\u0941\u0928 \u0917\u093e\u0935\u093e\u0915\u0921\u0947 \u0928\u093f\u0918\u093e\u0932\u0947\u0932\u094d\u092f\u093e \u0924\u0930\u0941\u0923\u093e\u0902\u091a\u093e \u0905\u092a\u0918\u093e\u0924 \u091d\u093e\u0932\u093e. \u092f\u093e\u092e\u0927\u094d\u092f\u0947 \u090f\u0915\u093e \u0924\u0930\u0941\u0923\u093e\u091a\u093e \u092e\u0943\u0924\u094d\u092f\u0942 \u091d\u093e\u0932\u093e.",
#             "publishedAt": "2023-09-17T15:14:06Z",
#             "source": {
#                 "id": null,
#                 "name": "Maharashtratimes.com"
#             },
#             "title": "\u092e\u0941\u0902\u092c\u0908\u0939\u0942\u0928 \u0926\u094b\u0918\u0947 \u0926\u0941\u091a\u093e\u0915\u0940\u0935\u0930\u0941\u0928 \u092a\u0939\u093e\u091f\u0947 \u0915\u094b\u0915\u0923\u093e\u0924\u0940\u0932 \u0917\u093e\u0935\u093e\u0915\u0921\u0947 \u0928\u093f\u0918\u093e\u0932\u0947, \u0913\u0935\u094d\u0939\u0930\u091f\u0947\u0915 \u0915\u0930\u0924\u093e\u0928\u093e \u0928\u093f\u092f\u0902\u0924\u094d\u0930\u0923 \u0938\u0941\u091f\u0932\u0902 \u0905\u0928\u094d \u0905\u0928\u0930\u094d\u0925, \u090f\u0915\u093e\u091a\u093e \u092e\u0943\u0924\u094d\u092f\u0942",
#             "url": "https://maharashtratimes.com/maharashtra/ratnagiri/ratnagiri-news-another-bike-accident-on-mumbai-goa-high-way-youth-died-at-savarde/articleshow/103736957.cms",
#             "urlToImage": "https://static.langimg.com/photo/imgsize-234030,msid-103737083/maharashtra-times.jpg"
#         },
#         {
#             "author": "Sidhartha",
#             "content": "Inspiring 8 quotes by Keanu Reeves that would make you want to be a better person",
#             "description": "Goa has the lowest tax rates on liquor in India, resulting in cheaper prices compared to neighboring states like Karnataka and Maharashtra. An analysis by The International Spirits and Wines Association of India estimates that a bottle of spirits that costs R\u2026",
#             "publishedAt": "2023-09-24T19:24:50Z",
#             "source": {
#                 "id": "the-times-of-india",
#                 "name": "The Times of India"
#             },
#             "title": "Liquor price list: Goa cheapest, Karnataka tops",
#             "url": "https://timesofindia.indiatimes.com/business/liquor-price-list-goa-cheapest-karnataka-tops/articleshow/103914058.cms",
#             "urlToImage": "https://static.toiimg.com/thumb/msid-103914062,width-1070,height-580,imgsize-2132229,resizemode-75,overlay-toi_sw,pt-32,y_pad-40/photo.jpg"
#         },
#         {
#             "author": "Luis",
#             "content": "Cheap, Air France / KLM flights from UK cities to Mumbai for \u00a3335 for a round trip..Always wanted to explore India? This is an awesome chance to visit this incredible country at a more than affordabl\u2026 [+1335 chars]",
#             "description": "Cheap, Air France / KLM flights from UK cities to Mumbai for \u00a3335 for a round trip..",
#             "publishedAt": "2023-10-04T07:30:46Z",
#             "source": {
#                 "id": null,
#                 "name": "Fly4free.com"
#             },
#             "title": "Cheap flights from the UK to Mumbai for \u00a3335",
#             "url": "https://www.fly4free.com/flight-deals/europe/cheap-flights-from-the-uk-to-mumbai-for-335/",
#             "urlToImage": "https://assets.fly4free.com/wp-content/uploads/2023/08/Mumbai-800x600.jpg"
#         },
#         {
#             "author": "Shivendra Kumar",
#             "content": "JSW Infrastructure has fixed the price band for its upcoming initial public offer (IPO) at Rs 113-119 per share. The public offer of the ports business of Sajjan Jindal-led JSW Group will run for sub\u2026 [+1991 chars]",
#             "description": "The company's business operations expanded from one port concession at Mormugao Port Trust in Goa (acquired by JSW in 2002 and commenced operations in 2004) to nine port concessions across the eastern and western coast of India, making it a well-diversified m\u2026",
#             "publishedAt": "2023-09-18T04:03:14Z",
#             "source": {
#                 "id": "the-times-of-india",
#                 "name": "The Times of India"
#             },
#             "title": "JSW Infra sets IPO price band at Rs 113-119, looks to raise Rs 2800 crore",
#             "url": "https://economictimes.indiatimes.com/markets/ipos/fpos/jsw-infra-sets-ipo-price-band-at-rs-113-119-looks-to-raise-rs-2800-crore/articleshow/103745330.cms",
#             "urlToImage": "https://economictimes.indiatimes.com/thumb/msid-103745421,width-1070,height-580,imgsize-45154,overlay-etmarkets/photo.jpg"
#         },
#         {
#             "author": "Abhishek Law",
#             "content": "Post success of luxury river cruise Ganga Vilas, international majors like Costa, and some others, are tapping into the segment.\r\nCome November, Costa will start coastal cruise ops in India, along ro\u2026 [+2878 chars]",
#             "description": "Int'l majors tap into luxury river cruise segment in India; Costa to start coastal ops in Nov; 4 other operators exploring Ganges, Brahmaputra routes; Cordelia Cruises active on TN-SL, Mumbai-Goa, Lakshadweep routes; Sittwe port, Kolkata-Varanasi, Guwahati-Jo\u2026",
#             "publishedAt": "2023-09-30T12:44:29Z",
#             "source": {
#                 "id": null,
#                 "name": "BusinessLine"
#             },
#             "title": "River, coastal cruise tourism in India witnessing interest from international majors, Costa Cruise: Sarbananda Sonowal",
#             "url": "https://www.thehindubusinessline.com/economy/logistics/river-coastal-cruise-tourism-in-india-witnessing-interest-from-international-majors-costa-cruise-sarbananda-sonowal/article67365476.ece",
#             "urlToImage": "https://bl-i.thgim.com/public/incoming/oqvm2u/article65542393.ece/alternates/LANDSCAPE_1200/ganga-vilas-scaled.jpg"
#         },
#         {
#             "author": "Live from a Lounge",
#             "content": "While Fuel Surcharge is a \u201cbad word\u201d in the context of airfares, sometimes airlines have to do it, and sometimes they use the term loosely to take money out of your pocket. Today, IndiGo, India\u2019s lar\u2026 [+2735 chars]",
#             "description": "IndiGo has announced the application of new heading in the fares, fuel surcharges, effective October 6, 2023. Here are the details. \nThe post IndiGo to levy Fuel Surcharge effective October 6, 2023 appeared first on Live from a Lounge.",
#             "publishedAt": "2023-10-05T11:26:42Z",
#             "source": {
#                 "id": null,
#                 "name": "Livefromalounge.com"
#             },
#             "title": "IndiGo to levy Fuel Surcharge effective October 6, 2023",
#             "url": "https://livefromalounge.com/indigo-to-levy-fuel-surcharge-effective-october-6-2023/",
#             "urlToImage": "https://livefromalounge.com/wp-content/uploads/2019/03/e153d23f-eb43-43f3-bb12-536e1c62bac1.jpg"
#         },
#         {
#             "author": "Aneesh Phadnis",
#             "content": "It is a contest between infrastructure and incentives as Goas two airports compete for air traffic a first-of-its-kind battle given the proximity of the two airports to each other in the tiny State.\u00a0\u2026 [+2631 chars]",
#             "description": "Competition between Goa's two airports, Mopa and Dabolim, for air traffic is a first-of-its-kind battle. Mopa offers round-the-clock services, while AAI is trying to lure airlines with incentives. Dabolim has 55-60 daily departures, while Mopa is built to han\u2026",
#             "publishedAt": "2023-10-04T15:07:24Z",
#             "source": {
#                 "id": null,
#                 "name": "BusinessLine"
#             },
#             "title": "Mopa vs Dabolim: Goa\u2019s two\u00a0airports slug it out to lure more flights",
#             "url": "https://www.thehindubusinessline.com/news/national/mopa-vs-dabolim-goas-two-airports-slug-it-out-to-lure-more-flights/article67381100.ece",
#             "urlToImage": "https://bl-i.thgim.com/public/incoming/ct321t/article67381109.ece/alternates/LANDSCAPE_1200/PTI12_10_2022_000060B.jpg"
#         },
#         {
#             "author": null,
#             "content": "Rahul Gandhi went to Goa, in August, to bring Noorie, a Jack Russell Terrier puppy, home\r\nCongress leader Rahul Gandhi has introduced the world to the newest member of his family \u00a0 a pet dog named No\u2026 [+1747 chars]",
#             "description": "Congress leader Rahul Gandhi has introduced the world to the newest member of his family   a pet dog named Noorie. It is Mr Gandhi's little surprise for his mother, ex-Congress chief Sonia Gandhi.",
#             "publishedAt": "2023-10-04T10:33:57Z",
#             "source": {
#                 "id": null,
#                 "name": "NDTV News"
#             },
#             "title": "Watch: Rahul Gandhi's \"Little Surprise For Ma\" From His Goa Trip",
#             "url": "https://www.ndtv.com/india-news/rahul-gandhi-surprises-mother-sonia-gandhi-with-pet-dog-noorie-4449070",
#             "urlToImage": "https://c.ndtvimg.com/2023-10/ott87vbc_rahul-gandhisonia-gandhi-dog_625x300_04_October_23.jpg"
#         }
#     ],
#     "status": "ok",
#     "totalResults": 465
# }
#   source.id             source.name                author  \
# 0      None      The Indian Express  Pavneet Singh Chadha
# 1      None      The Indian Express    Entertainment Desk
# 2      None      The Indian Express  Pavneet Singh Chadha
# 3      None      The Indian Express  Pavneet Singh Chadha
# 4      None  Courrier International                  None
#
#                                                title  \
# 0  Sun, sand and spirituality – how Goa plans to ...
# 1  How Amitabh Bachchan found a home in Mehmood’s...
# 2  Goa minister: Portuguese committed atrocities,...
# 3  Day after reshuffle, AAP Goa vice president Pr...
# 4  L’État indien de Goa submergé par les nomades ...
#
#                                          description  \
# 0  Tourism department officials said Goa is large...
# 1  Mehmood's brother Anwar Ali recalled the time ...
# 2  Emphasising the importance of preserving and s...
# 3  In a letter to the party's national convener A...
# 4  Les autorités locales avaient misé sur la venu...
#
#                                                  url  \
# 0  https://indianexpress.com/article/india/sun-sa...
# 1  https://indianexpress.com/article/entertainmen...
# 2  https://indianexpress.com/article/india/goa-mi...
# 3  https://indianexpress.com/article/cities/goa/d...
# 4  https://www.courrierinternational.com/article/...
#
#                                           urlToImage           publishedAt  \
# 0  https://images.indianexpress.com/2023/10/Goa-t...  2023-10-05T09:02:14Z
# 1  https://images.indianexpress.com/2023/10/amita...  2023-10-12T07:41:41Z
# 2  https://images.indianexpress.com/2023/09/Goa-5...  2023-09-26T18:05:25Z
# 3  https://images.indianexpress.com/2023/09/AAP-G...  2023-09-28T04:10:12Z
# 4  https://focus.courrierinternational.com/2023/0...  2023-10-06T07:06:02Z
#
#                                              content
# 0  Spiritual circuits, temple trails, flights to ...
# 1  In his early days in the Hindi film industry, ...
# 2  Goa Minister for Archives and Archaeology Subh...
# 3  A day after being appointed as AAP’s state vic...
# 4  Cest la face obscure du nomadisme numérique qu...

# %% [markdown]
# ## NOAA World Data

# %%
url = "https://www.nnvl.noaa.gov/view/globaldata.html"
r = requests.get(url)

# %%
soup = BeautifulSoup(r.content, 'html.parser')
rows = soup.find("table").find_all("tr")[2:-2]
 
for row in rows:
    data = row.find_all("td")
    fileName = data[0].text
    lastModified = data[1].text
    if lastModified == '2022-02-07 14:03':
        break

# %%
newUrl = url+fileName
response = requests.get(newUrl)
name = 'new.csv'
open(name,'wb').write(response.content)
chunksize = 10000
tfr = pd.read_csv(name, chunksize=chunksize, iterator=True,low_memory=False)
df = pd.concat(tfr, ignore_index=True)
maxVal = int(df['HourlyDryBulbTemperature'].str.replace('s','').astype('float').max())
res = df.loc[ df['HourlyDryBulbTemperature'] == str(maxVal) ]
print(res)
# Out:
#            STATION                 DATE  LATITUDE  LONGITUDE  ELEVATION  \
# 14605  A5125500445  2021-07-29T14:55:00  32.46383  -87.95405       34.1
# 14606  A5125500445  2021-07-29T15:15:00  32.46383  -87.95405       34.1
# 14785  A5125500445  2021-08-01T13:55:00  32.46383  -87.95405       34.1
#
#                                      NAME REPORT_TYPE SOURCE  \
# 14605  DEMOPOLIS MUNICIPAL AIRPORT, AL US       FM-15      6
# 14606  DEMOPOLIS MUNICIPAL AIRPORT, AL US       FM-15      6
# 14785  DEMOPOLIS MUNICIPAL AIRPORT, AL US       FM-15      6
#
#        HourlyAltimeterSetting  HourlyDewPointTemperature  ... BackupDirection  \
# 14605                   29.99                       76.0  ...             NaN
# 14606                   29.99                       74.0  ...             NaN
# 14785                   29.96                       74.0  ...             NaN
#
#        BackupDistance BackupDistanceUnit  BackupElements  BackupElevation  \
# 14605             NaN                NaN             NaN              NaN
# 14606             NaN                NaN             NaN              NaN
# 14785             NaN                NaN             NaN              NaN
#
#        BackupEquipment BackupLatitude  BackupLongitude  BackupName  \
# 14605              NaN            NaN              NaN         NaN
# 14606              NaN            NaN              NaN         NaN
# 14785              NaN            NaN              NaN         NaN
#
#       WindEquipmentChangeDate
# 14605                     NaN
# 14606                     NaN
# 14785                     NaN
#
# [3 rows x 125 columns]

# %% [markdown]
# ## Bureau of Economic Analysis

# %%
url = "https://www.nnvl.noaa.gov/view/globaldata.html"
r = requests.get(url)
